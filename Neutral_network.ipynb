# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import keras
import os
from keras.layers import Dense
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pd.__version__))
print('Numpy: {}'.format(np.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Matplotlib: {}'.format(matplotlib.__version__))
print('Keras: {}'.format(keras.__version__))
# Out:
# Python: 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# Pandas: 1.1.5
# Numpy: 1.19.5
# Sklearn: 1.0.1
# Matplotlib: 3.2.2
# Keras: 2.7.0

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
# read the csv
cleveland = pd.read_csv("/content/drive/MyDrive/dataset/heart.csv")

# %%
# print the shape of the DataFrame, so we can see how many examples we have
print( 'Shape of DataFrame: {}'.format(cleveland.shape))
print (cleveland.loc[1])
# Out:
# Shape of DataFrame: (303, 14)
# age          37.0
# sex           1.0
# cp            2.0
# trestbps    130.0
# chol        250.0
# fbs           0.0
# restecg       1.0
# thalach     187.0
# exang         0.0
# oldpeak       3.5
# slope         0.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 1, dtype: float64

# %%
# print the last twenty or so data points
cleveland.loc[280:]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 280   42    1   0       136   315    0  ...      1      1.8      1   0     1       0
# 281   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 282   59    1   2       126   218    1  ...      0      2.2      1   1     1       0
# 283   40    1   0       152   223    0  ...      0      0.0      2   0     3       0
# 284   61    1   0       140   207    0  ...      1      1.9      2   1     3       0
# 285   46    1   0       140   311    0  ...      1      1.8      1   2     3       0
# 286   59    1   3       134   204    0  ...      0      0.8      2   2     2       0
# 287   57    1   1       154   232    0  ...      0      0.0      2   1     2       0
# 288   57    1   0       110   335    0  ...      1      3.0      1   1     3       0
# 289   55    0   0       128   205    0  ...      1      2.0      1   1     3       0
# 290   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 291   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 292   58    0   0       170   225    1  ...      1      2.8      1   2     1       0
# 293   67    1   2       152   212    0  ...      0      0.8      1   0     3       0
# 294   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
# 295   63    1   0       140   187    0  ...      1      4.0      2   2     3       0
# 296   63    0   0       124   197    0  ...      1      0.0      1   0     2       0
# 297   59    1   0       164   176    1  ...      0      1.0      1   2     1       0
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [23 rows x 14 columns]

# %%
# remove missing data (indicated with a "?")
data = cleveland[~cleveland.isin(['?'])]
data.loc[280:]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 280   42    1   0       136   315    0  ...      1      1.8      1   0     1       0
# 281   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 282   59    1   2       126   218    1  ...      0      2.2      1   1     1       0
# 283   40    1   0       152   223    0  ...      0      0.0      2   0     3       0
# 284   61    1   0       140   207    0  ...      1      1.9      2   1     3       0
# 285   46    1   0       140   311    0  ...      1      1.8      1   2     3       0
# 286   59    1   3       134   204    0  ...      0      0.8      2   2     2       0
# 287   57    1   1       154   232    0  ...      0      0.0      2   1     2       0
# 288   57    1   0       110   335    0  ...      1      3.0      1   1     3       0
# 289   55    0   0       128   205    0  ...      1      2.0      1   1     3       0
# 290   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 291   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 292   58    0   0       170   225    1  ...      1      2.8      1   2     1       0
# 293   67    1   2       152   212    0  ...      0      0.8      1   0     3       0
# 294   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
# 295   63    1   0       140   187    0  ...      1      4.0      2   2     3       0
# 296   63    0   0       124   197    0  ...      1      0.0      1   0     2       0
# 297   59    1   0       164   176    1  ...      0      1.0      1   2     1       0
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [23 rows x 14 columns]

# %%
# drop rows with NaN values from DataFrame
data = data.dropna(axis=0)
data.loc[280:]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 280   42    1   0       136   315    0  ...      1      1.8      1   0     1       0
# 281   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 282   59    1   2       126   218    1  ...      0      2.2      1   1     1       0
# 283   40    1   0       152   223    0  ...      0      0.0      2   0     3       0
# 284   61    1   0       140   207    0  ...      1      1.9      2   1     3       0
# 285   46    1   0       140   311    0  ...      1      1.8      1   2     3       0
# 286   59    1   3       134   204    0  ...      0      0.8      2   2     2       0
# 287   57    1   1       154   232    0  ...      0      0.0      2   1     2       0
# 288   57    1   0       110   335    0  ...      1      3.0      1   1     3       0
# 289   55    0   0       128   205    0  ...      1      2.0      1   1     3       0
# 290   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 291   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 292   58    0   0       170   225    1  ...      1      2.8      1   2     1       0
# 293   67    1   2       152   212    0  ...      0      0.8      1   0     3       0
# 294   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
# 295   63    1   0       140   187    0  ...      1      4.0      2   2     3       0
# 296   63    0   0       124   197    0  ...      1      0.0      1   0     2       0
# 297   59    1   0       164   176    1  ...      0      1.0      1   2     1       0
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [23 rows x 14 columns]

# %%
# print the shape and data type of the dataframe
print(data.shape)
print(data.dtypes)
# Out:
# (303, 14)
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# transform data to numeric to enable further analysis
data = data.apply(pd.to_numeric)
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# print data characteristics, usings pandas built-in describe() function
data.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
# plot histograms for each variable
data.hist(figsize = (12, 12))
plt.show()

# %%
pd.crosstab(data.age,data.target).plot(kind="bar",figsize=(20,6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,fmt='.1f')
plt.show()

# %%
age_unique=sorted(data.age.unique())
age_thalach_values=data.groupby('age')['thalach'].count().values
mean_thalach=[]
for i,age in enumerate(age_unique):
    mean_thalach.append(sum(data[data['age']==age].thalach)/age_thalach_values[i])
    
plt.figure(figsize=(10,5))
sns.pointplot(x=age_unique,y=mean_thalach,color='red',alpha=0.8)
plt.xlabel('Age',fontsize = 15,color='blue')
plt.xticks(rotation=45)
plt.ylabel('Thalach',fontsize = 15,color='blue')
plt.title('Age vs Thalach',fontsize = 15,color='blue')
plt.grid()
plt.show()

# %%
# At this moment we have a dataframe that contains all of the heart.csv data. However we need to
# Separate them to [X, Y]. Where our target labels are 'Y', and 'X' is our training data.
Y = data.target.values
X = data.drop(['target'], axis=1)

# Now split to train/test with 80% training data, and 20% test data.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Check dimensions of both sets.
print("Train Features Size:", X_train.shape)
print("Test Features Size:", X_test.shape)
print("Train Labels Size:", Y_train.shape)
print("Test Labels Size:", Y_test.shape)
# Out:
# Train Features Size: (242, 13)
# Test Features Size: (61, 13)
# Train Labels Size: (242,)
# Test Labels Size: (61,)

# %%
# Define a Neural Network Model

def NN_model(learning_rate):
    model = Sequential()
    model.add(Dense(32, input_dim=13, kernel_initializer='normal', activation='relu'))
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(2, activation='softmax'))
    Adam(lr=learning_rate)
    model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %%
# Build a NN-model, and start training
learning_rate = 0.01
model = NN_model(learning_rate)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                448
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 1,010
# Trainable params: 1,010
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=16, verbose=2)
# Out:
# Epoch 1/100
# 16/16 - 1s - loss: 0.6466 - accuracy: 0.6488 - val_loss: 0.9134 - val_accuracy: 0.5246
# Epoch 2/100
# 16/16 - 0s - loss: 0.7546 - accuracy: 0.5372 - val_loss: 0.5491 - val_accuracy: 0.6721
# Epoch 3/100
# 16/16 - 0s - loss: 0.6636 - accuracy: 0.5992 - val_loss: 0.6144 - val_accuracy: 0.6721
# Epoch 4/100
# 16/16 - 0s - loss: 0.6059 - accuracy: 0.6446 - val_loss: 0.5234 - val_accuracy: 0.8361
# Epoch 5/100
# 16/16 - 0s - loss: 0.5829 - accuracy: 0.6860 - val_loss: 0.5521 - val_accuracy: 0.6721
# Epoch 6/100
# 16/16 - 0s - loss: 0.6258 - accuracy: 0.6281 - val_loss: 0.5278 - val_accuracy: 0.7541
# Epoch 7/100
# 16/16 - 0s - loss: 0.6165 - accuracy: 0.6777 - val_loss: 0.6279 - val_accuracy: 0.6393
# Epoch 8/100
# 16/16 - 0s - loss: 0.5984 - accuracy: 0.6736 - val_loss: 0.5362 - val_accuracy: 0.7213
# Epoch 9/100
# 16/16 - 0s - loss: 0.6025 - accuracy: 0.6736 - val_loss: 0.5049 - val_accuracy: 0.7869
# Epoch 10/100
# 16/16 - 0s - loss: 0.5760 - accuracy: 0.7190 - val_loss: 0.5265 - val_accuracy: 0.7705
# Epoch 11/100
# 16/16 - 0s - loss: 0.5737 - accuracy: 0.7066 - val_loss: 0.5025 - val_accuracy: 0.8033
# Epoch 12/100
# 16/16 - 0s - loss: 0.5527 - accuracy: 0.7190 - val_loss: 0.4951 - val_accuracy: 0.8033
# Epoch 13/100
# 16/16 - 0s - loss: 0.5511 - accuracy: 0.7066 - val_loss: 0.4671 - val_accuracy: 0.8033
# Epoch 14/100
# 16/16 - 0s - loss: 0.5612 - accuracy: 0.7066 - val_loss: 0.4877 - val_accuracy: 0.7541
# Epoch 15/100
# 16/16 - 0s - loss: 0.5447 - accuracy: 0.6983 - val_loss: 0.4815 - val_accuracy: 0.7705
# Epoch 16/100
# 16/16 - 0s - loss: 0.5562 - accuracy: 0.7066 - val_loss: 0.4622 - val_accuracy: 0.8361
# Epoch 17/100
# 16/16 - 0s - loss: 0.5354 - accuracy: 0.7314 - val_loss: 0.4569 - val_accuracy: 0.7869
# Epoch 18/100
# 16/16 - 0s - loss: 0.5323 - accuracy: 0.7355 - val_loss: 0.4856 - val_accuracy: 0.7377
# Epoch 19/100
# 16/16 - 0s - loss: 0.5229 - accuracy: 0.7397 - val_loss: 0.4375 - val_accuracy: 0.8361
# Epoch 20/100
# 16/16 - 0s - loss: 0.5111 - accuracy: 0.7769 - val_loss: 0.4814 - val_accuracy: 0.7705
# Epoch 21/100
# 16/16 - 0s - loss: 0.5350 - accuracy: 0.7190 - val_loss: 0.4530 - val_accuracy: 0.8033
# Epoch 22/100
# 16/16 - 0s - loss: 0.5054 - accuracy: 0.7397 - val_loss: 0.4283 - val_accuracy: 0.8361
# Epoch 23/100
# 16/16 - 0s - loss: 0.4953 - accuracy: 0.7314 - val_loss: 0.4569 - val_accuracy: 0.7869
# Epoch 24/100
# 16/16 - 0s - loss: 0.5045 - accuracy: 0.7355 - val_loss: 0.4604 - val_accuracy: 0.7869
# Epoch 25/100
# 16/16 - 0s - loss: 0.5011 - accuracy: 0.7645 - val_loss: 0.4191 - val_accuracy: 0.8361
# Epoch 26/100
# 16/16 - 0s - loss: 0.5424 - accuracy: 0.7190 - val_loss: 0.4033 - val_accuracy: 0.8525
# Epoch 27/100
# 16/16 - 0s - loss: 0.4791 - accuracy: 0.7686 - val_loss: 0.4458 - val_accuracy: 0.8197
# Epoch 28/100
# 16/16 - 0s - loss: 0.4779 - accuracy: 0.7810 - val_loss: 0.4192 - val_accuracy: 0.8033
# Epoch 29/100
# 16/16 - 0s - loss: 0.4832 - accuracy: 0.7727 - val_loss: 0.3937 - val_accuracy: 0.8525
# Epoch 30/100
# 16/16 - 0s - loss: 0.4812 - accuracy: 0.7438 - val_loss: 0.3909 - val_accuracy: 0.8525
# Epoch 31/100
# 16/16 - 0s - loss: 0.5229 - accuracy: 0.7273 - val_loss: 0.3940 - val_accuracy: 0.8525
# Epoch 32/100
# 16/16 - 0s - loss: 0.4667 - accuracy: 0.7727 - val_loss: 0.4140 - val_accuracy: 0.8361
# Epoch 33/100
# 16/16 - 0s - loss: 0.4719 - accuracy: 0.7603 - val_loss: 0.3793 - val_accuracy: 0.8525
# Epoch 34/100
# 16/16 - 0s - loss: 0.4665 - accuracy: 0.7686 - val_loss: 0.3835 - val_accuracy: 0.8525
# Epoch 35/100
# 16/16 - 0s - loss: 0.4430 - accuracy: 0.7851 - val_loss: 0.3830 - val_accuracy: 0.8525
# Epoch 36/100
# 16/16 - 0s - loss: 0.4420 - accuracy: 0.7810 - val_loss: 0.3731 - val_accuracy: 0.8525
# Epoch 37/100
# 16/16 - 0s - loss: 0.4540 - accuracy: 0.7810 - val_loss: 0.3637 - val_accuracy: 0.8525
# Epoch 38/100
# 16/16 - 0s - loss: 0.4210 - accuracy: 0.8058 - val_loss: 0.3852 - val_accuracy: 0.8525
# Epoch 39/100
# 16/16 - 0s - loss: 0.4210 - accuracy: 0.8140 - val_loss: 0.3906 - val_accuracy: 0.8525
# Epoch 40/100
# 16/16 - 0s - loss: 0.4658 - accuracy: 0.7893 - val_loss: 0.3763 - val_accuracy: 0.8689
# Epoch 41/100
# 16/16 - 0s - loss: 0.4112 - accuracy: 0.8223 - val_loss: 0.3677 - val_accuracy: 0.8525
# Epoch 42/100
# 16/16 - 0s - loss: 0.4326 - accuracy: 0.7893 - val_loss: 0.3658 - val_accuracy: 0.8689
# Epoch 43/100
# 16/16 - 0s - loss: 0.4271 - accuracy: 0.8058 - val_loss: 0.4101 - val_accuracy: 0.8197
# Epoch 44/100
# 16/16 - 0s - loss: 0.4436 - accuracy: 0.7645 - val_loss: 0.3619 - val_accuracy: 0.8689
# Epoch 45/100
# 16/16 - 0s - loss: 0.4488 - accuracy: 0.7810 - val_loss: 0.3568 - val_accuracy: 0.8689
# Epoch 46/100
# 16/16 - 0s - loss: 0.4220 - accuracy: 0.8264 - val_loss: 0.3545 - val_accuracy: 0.8689
# Epoch 47/100
# 16/16 - 0s - loss: 0.3974 - accuracy: 0.8347 - val_loss: 0.3935 - val_accuracy: 0.8361
# Epoch 48/100
# 16/16 - 0s - loss: 0.3999 - accuracy: 0.8223 - val_loss: 0.4012 - val_accuracy: 0.8197
# Epoch 49/100
# 16/16 - 0s - loss: 0.3974 - accuracy: 0.8182 - val_loss: 0.4576 - val_accuracy: 0.7869
# Epoch 50/100
# 16/16 - 0s - loss: 0.3970 - accuracy: 0.8306 - val_loss: 0.3682 - val_accuracy: 0.8689
# Epoch 51/100
# 16/16 - 0s - loss: 0.4473 - accuracy: 0.7603 - val_loss: 0.3521 - val_accuracy: 0.8852
# Epoch 52/100
# 16/16 - 0s - loss: 0.4112 - accuracy: 0.8058 - val_loss: 0.4626 - val_accuracy: 0.7541
# Epoch 53/100
# 16/16 - 0s - loss: 0.4410 - accuracy: 0.7934 - val_loss: 0.3566 - val_accuracy: 0.8689
# Epoch 54/100
# 16/16 - 0s - loss: 0.6243 - accuracy: 0.6860 - val_loss: 0.3568 - val_accuracy: 0.8689
# Epoch 55/100
# 16/16 - 0s - loss: 0.4551 - accuracy: 0.7810 - val_loss: 0.4317 - val_accuracy: 0.8361
# Epoch 56/100
# 16/16 - 0s - loss: 0.4435 - accuracy: 0.8182 - val_loss: 0.3498 - val_accuracy: 0.8852
# Epoch 57/100
# 16/16 - 0s - loss: 0.4043 - accuracy: 0.8140 - val_loss: 0.3545 - val_accuracy: 0.8689
# Epoch 58/100
# 16/16 - 0s - loss: 0.4066 - accuracy: 0.8264 - val_loss: 0.3867 - val_accuracy: 0.8525
# Epoch 59/100
# 16/16 - 0s - loss: 0.3918 - accuracy: 0.8306 - val_loss: 0.3563 - val_accuracy: 0.8852
# Epoch 60/100
# 16/16 - 0s - loss: 0.4261 - accuracy: 0.8058 - val_loss: 0.3638 - val_accuracy: 0.8852
# Epoch 61/100
# 16/16 - 0s - loss: 0.3896 - accuracy: 0.8264 - val_loss: 0.3472 - val_accuracy: 0.8852
# Epoch 62/100
# 16/16 - 0s - loss: 0.3868 - accuracy: 0.8264 - val_loss: 0.3697 - val_accuracy: 0.8689
# Epoch 63/100
# 16/16 - 0s - loss: 0.4394 - accuracy: 0.7934 - val_loss: 0.3540 - val_accuracy: 0.8852
# Epoch 64/100
# 16/16 - 0s - loss: 0.4095 - accuracy: 0.8099 - val_loss: 0.4382 - val_accuracy: 0.8033
# Epoch 65/100
# 16/16 - 0s - loss: 0.4372 - accuracy: 0.7851 - val_loss: 0.5560 - val_accuracy: 0.7213
# Epoch 66/100
# 16/16 - 0s - loss: 0.3817 - accuracy: 0.8182 - val_loss: 0.3521 - val_accuracy: 0.8689
# Epoch 67/100
# 16/16 - 0s - loss: 0.3803 - accuracy: 0.8471 - val_loss: 0.3552 - val_accuracy: 0.8852
# Epoch 68/100
# 16/16 - 0s - loss: 0.3873 - accuracy: 0.8223 - val_loss: 0.3678 - val_accuracy: 0.8852
# Epoch 69/100
# 16/16 - 0s - loss: 0.3789 - accuracy: 0.8306 - val_loss: 0.3519 - val_accuracy: 0.8852
# Epoch 70/100
# 16/16 - 0s - loss: 0.3800 - accuracy: 0.8347 - val_loss: 0.3725 - val_accuracy: 0.8852
# Epoch 71/100
# 16/16 - 0s - loss: 0.3921 - accuracy: 0.8058 - val_loss: 0.4335 - val_accuracy: 0.8033
# Epoch 72/100
# 16/16 - 0s - loss: 0.4320 - accuracy: 0.7975 - val_loss: 0.5678 - val_accuracy: 0.6885
# Epoch 73/100
# 16/16 - 0s - loss: 0.4348 - accuracy: 0.7934 - val_loss: 0.3888 - val_accuracy: 0.8525
# Epoch 74/100
# 16/16 - 0s - loss: 0.3729 - accuracy: 0.8347 - val_loss: 0.3661 - val_accuracy: 0.8852
# Epoch 75/100
# 16/16 - 0s - loss: 0.3828 - accuracy: 0.8471 - val_loss: 0.3797 - val_accuracy: 0.8689
# Epoch 76/100
# 16/16 - 0s - loss: 0.3738 - accuracy: 0.8306 - val_loss: 0.4173 - val_accuracy: 0.8033
# Epoch 77/100
# 16/16 - 0s - loss: 0.4020 - accuracy: 0.7975 - val_loss: 0.3834 - val_accuracy: 0.8689
# Epoch 78/100
# 16/16 - 0s - loss: 0.3701 - accuracy: 0.8347 - val_loss: 0.4289 - val_accuracy: 0.8033
# Epoch 79/100
# 16/16 - 0s - loss: 0.3883 - accuracy: 0.8140 - val_loss: 0.5554 - val_accuracy: 0.7377
# Epoch 80/100
# 16/16 - 0s - loss: 0.4286 - accuracy: 0.7851 - val_loss: 0.4281 - val_accuracy: 0.8033
# Epoch 81/100
# 16/16 - 0s - loss: 0.4022 - accuracy: 0.8017 - val_loss: 0.3624 - val_accuracy: 0.8852
# Epoch 82/100
# 16/16 - 0s - loss: 0.3669 - accuracy: 0.8636 - val_loss: 0.3589 - val_accuracy: 0.8689
# Epoch 83/100
# 16/16 - 0s - loss: 0.3740 - accuracy: 0.8347 - val_loss: 0.3755 - val_accuracy: 0.8689
# Epoch 84/100
# 16/16 - 0s - loss: 0.3882 - accuracy: 0.8430 - val_loss: 0.3620 - val_accuracy: 0.8689
# Epoch 85/100
# 16/16 - 0s - loss: 0.3676 - accuracy: 0.8430 - val_loss: 0.3851 - val_accuracy: 0.8525
# Epoch 86/100
# 16/16 - 0s - loss: 0.3766 - accuracy: 0.8388 - val_loss: 0.4203 - val_accuracy: 0.8197
# Epoch 87/100
# 16/16 - 0s - loss: 0.4733 - accuracy: 0.7810 - val_loss: 0.3682 - val_accuracy: 0.8689
# Epoch 88/100
# 16/16 - 0s - loss: 0.3767 - accuracy: 0.8306 - val_loss: 0.3755 - val_accuracy: 0.8689
# Epoch 89/100
# 16/16 - 0s - loss: 0.3664 - accuracy: 0.8430 - val_loss: 0.3673 - val_accuracy: 0.8689
# Epoch 90/100
# 16/16 - 0s - loss: 0.3774 - accuracy: 0.8099 - val_loss: 0.4470 - val_accuracy: 0.7869
# Epoch 91/100
# 16/16 - 0s - loss: 0.3887 - accuracy: 0.8306 - val_loss: 0.4207 - val_accuracy: 0.8197
# Epoch 92/100
# 16/16 - 0s - loss: 0.3517 - accuracy: 0.8388 - val_loss: 0.3845 - val_accuracy: 0.8525
# Epoch 93/100
# 16/16 - 0s - loss: 0.4085 - accuracy: 0.8017 - val_loss: 0.3582 - val_accuracy: 0.8689
# Epoch 94/100
# 16/16 - 0s - loss: 0.3948 - accuracy: 0.8182 - val_loss: 0.3729 - val_accuracy: 0.8689
# Epoch 95/100
# 16/16 - 0s - loss: 0.3680 - accuracy: 0.8512 - val_loss: 0.3575 - val_accuracy: 0.8852
# Epoch 96/100
# 16/16 - 0s - loss: 0.3598 - accuracy: 0.8554 - val_loss: 0.3721 - val_accuracy: 0.8852
# Epoch 97/100
# 16/16 - 0s - loss: 0.3574 - accuracy: 0.8554 - val_loss: 0.3993 - val_accuracy: 0.8689
# Epoch 98/100
# 16/16 - 0s - loss: 0.3548 - accuracy: 0.8554 - val_loss: 0.4692 - val_accuracy: 0.7869
# Epoch 99/100
# 16/16 - 0s - loss: 0.4243 - accuracy: 0.7851 - val_loss: 0.4190 - val_accuracy: 0.8197
# Epoch 100/100
# 16/16 - 0s - loss: 0.3653 - accuracy: 0.8306 - val_loss: 0.3817 - val_accuracy: 0.8689

# %%
# Plot the model accuracy vs. number of Epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'])
plt.show()

# Plot the Loss function vs. number of Epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'])
plt.show()

# %%
predictions = np.argmax(model.predict(X_test), axis=1)
model_accuracy = accuracy_score(Y_test, predictions)*100
print("Model Accracy:", model_accuracy,"%")
print(classification_report(Y_test, predictions))
# Out:
# Model Accracy: 86.88524590163934 %
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        29
#            1       0.88      0.88      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
